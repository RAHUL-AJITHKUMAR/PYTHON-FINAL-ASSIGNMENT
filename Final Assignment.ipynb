# %% [markdown]
# # COMPANY ABC COMPREHENSIVE REPORT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df=pd.read_excel('myexcel.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df['Height'] = np.random.randint(150, 181, size=len(df))  # Correcting Hieght colums with random numbers
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     176     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     150     235
# 2     John Holland  Boston Celtics      30       SG   27     168     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     158     235
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     180     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     167     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     153     203
# 456    Jeff Withey       Utah Jazz      24        C   26     157     231
# 457       Priyanka       Utah Jazz      34        C   25     161     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df.isnull().sum() # Ensuring data Consistency by checking for null if any
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
x = df['Salary'].mean()  # Data handling using mean value to fill salary whic are null
df['Salary'].fillna(x,inplace = True)
df
# Out:
# C:\Users\Ajith\AppData\Local\Temp\ipykernel_14992\1051062031.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(x,inplace = True)
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     179     235
# 2     John Holland  Boston Celtics      30       SG   27     179     205
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
df.dropna ( inplace = True) # Droping null rows to maintain data consistency and integrity
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     179     235
# 2     John Holland  Boston Celtics      30       SG   27     179     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     159     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     165     235
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     175     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     170     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     178     203
# 456    Jeff Withey       Utah Jazz      24        C   26     152     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# # Distrubtuion of employees across team and percentage split

# %%
# Number of employees per team
team_distribution = df["Team"].value_counts()

# percentage split
team_percentage = (team_distribution / len(df)) * 100

# DataFrame
team_summary = pd.DataFrame({"Employee Count": team_distribution, "Percentage": team_percentage})


plt.figure(figsize=(10,10))
plt.pie(team_summary["Employee Count"], labels=team_summary.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Percentage Split of Employees Across Teams")
plt.show()

team_summary
# Out:
#                         Employee Count  Percentage
# Team
# Memphis Grizzlies                   17    4.545455
# New Orleans Pelicans                16    4.278075
# Portland Trail Blazers              15    4.010695
# Philadelphia 76ers                  15    4.010695
# Detroit Pistons                     15    4.010695
# Milwaukee Bucks                     14    3.743316
# Oklahoma City Thunder               14    3.743316
# Los Angeles Clippers                14    3.743316
# Boston Celtics                      13    3.475936
# Washington Wizards                  13    3.475936
# Charlotte Hornets                   13    3.475936
# Phoenix Suns                        13    3.475936
# Sacramento Kings                    13    3.475936
# Brooklyn Nets                       13    3.475936
# Dallas Mavericks                    12    3.208556
# Indiana Pacers                      12    3.208556
# Cleveland Cavaliers                 12    3.208556
# ...

# %% [markdown]
# # Employees Distribution Based on the company position

# %%
# Count the number of employees in each position
position_distribution = df["Position"].value_counts()

# Convert to DataFrame
position_summary = pd.DataFrame({"Employee Count": position_distribution})



plt.figure(figsize=(12,6))
position_summary["Employee Count"].plot(kind="bar", color="lightcoral", edgecolor="black")

plt.xlabel("Positions")
plt.ylabel("Number of Employees")
plt.title("Employee Distribution by Position")
plt.xticks(rotation=45)
plt.show()


# Display results
position_stats
# Out:
#           Employee Count
# Position
# SG                    89
# PF                    84
# PG                    80
# SF                    71
# C                     50

# %% [markdown]
# # Which age group is Predominant ??

# %%
# bins and labels
bins = [18, 25, 30, 35, 40, 50, 60]  # Age group ranges
labels = ["18-25", "26-30", "31-35", "36-40", "41-50", "51-60"]  # Labels for age groups

# Categorize employees into age groups
df["Age Group"] = pd.cut(df["Age"], bins=bins, labels=labels, right=True)

# Count the number of employees in each age group
age_group_distribution = df["Age Group"].value_counts().sort_index()

# Convert to DataFrame for better presentation
age_group_df = pd.DataFrame({ "Age Group": age_group_distribution.index,"Employee Count": age_group_distribution.values})


# Predominant age group
predominant_age_group = age_group_distribution.idxmax()
print(f"\nPredominant Age Group: {predominant_age_group}")

age_group_df
# Out:
# Predominant Age Group: 18-25
#   Age Group  Employee Count
# 0     18-25             174
# 1     26-30             134
# 2     31-35              49
# 3     36-40              17
# 4     41-50               0
# 5     51-60               0

# %% [markdown]
# # Graphical Representation of Age distribution

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Age"], bins=10, kde=True, color="purple")

plt.xlabel("Age")
plt.ylabel("Number of Employees")
plt.title("Age Distribution of Employees")
plt.grid(True)
plt.show()plt.figure(figsize=(10,5))
sns.swarmplot(x=df["Age"], color="red")

plt.xlabel("Age")
plt.title("Swarm Plot of Employee Ages")
plt.show()

# %% [markdown]
# # Team and Position with Highest salary

# %%
# highest salary - team & position
highest_team = df.groupby("Team")["Salary"].sum().idxmax()
highest_team_amount = df.groupby("Team")["Salary"].sum().max()
highest_position = df.groupby("Position")["Salary"].sum().idxmax()
highest_position_amount = df.groupby("Position")["Salary"].sum().max()

# Print results
print(f"Team with Highest Salary Expenditure: {highest_team} - ${highest_team_amount:,.2f}")
print(f"Position with Highest Salary Expenditure: {highest_position} - ${highest_position_amount:,.2f}")
# Out:
# Team with Highest Salary Expenditure: Los Angeles Clippers - $93,906,914.00
# Position with Highest Salary Expenditure: PG - $392,957,136.18

# %% [markdown]
# # Finding out Correlation between Age and Salary

# %%
correlation = df["Age"].corr(df["Salary"])
print(f"Correlation between Age and Salary: {correlation:.2f}")

import plotly.express as px
fig = px.scatter(df, x="Age", y="Salary", 
                 title="Interactive Correlation Between Age and Salary",
                 labels={"Age": "Employee Age", "Salary": "Employee Salary ($)"},
                 trendline="ols",  # Add trendline for correlation
                 opacity=0.6, color=df["Age"], color_continuous_scale="Viridis")

fig.show()
# Out:
# Correlation between Age and Salary: 0.16
